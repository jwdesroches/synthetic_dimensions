# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)

from synth_dim_model import *

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import pandas as pd
import scipy

import warnings
warnings.filterwarnings("ignore")

# %%
N  = 2
M = 2
V = 0
mu = 10
J = 0

hamiltonian = construct_hamiltonian(N, M, V, mu, J)

times = np.linspace(0,1,1000)
hamiltonians = [hamiltonian for _ in times]

energy, eigenvectors = exact_diagonalize(hamiltonian)

initial_state = eigenvectors[0] + eigenvectors[1]
initial_state /= np.linalg.norm(initial_state)

energies, time_evolved_wavefunctions, state_probabilities, state_overlaps, true_energies, ground_state_manifold_overlaps = simulate_hamiltonian_time_evolution(hamiltonians, times, initial_state)

# %%
fig, ax = plt.subplots()
ax.plot(times, np.real(state_overlaps))

# %%
fig, ax = plt.subplots()
ax.plot(times, np.imag(state_overlaps))
