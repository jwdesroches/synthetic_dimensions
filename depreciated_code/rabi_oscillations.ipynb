# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
from synth_dim_model import *

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
dt = 0.01
T = 2

N = 1
M = 2

J = 10

times = np.linspace(0,T,int(T/dt))
J_V_ratios = np.linspace(J, J, int(T/dt))
mu_V_ratios = np.linspace(0,0, int(T/dt))

initial_state = [1,0]

adiabatic_energies, adiabatic_diff, adiabatic_wavefunctions, adiabatic_probabilities, adiabatic_overlaps, true_energies, energy_gaps = \
    simulate_adiabatic_evolution(N=N, M=M, V=-1, J_V_ratio_routine = J_V_ratios, mu_V_ratio_routine = mu_V_ratios, times = times, dt = dt, initial_state = initial_state)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 15
#      11 mu_V_ratios = np.linspace(0,0, int(T/dt))
#      13 initial_state = [1,0]
# ---> 15 adiabatic_energies, adiabatic_diff, adiabatic_wavefunctions, adiabatic_probabilities, adiabatic_overlaps, true_energies, energy_gaps = \
#      16     simulate_adiabatic_evolution(N=N, M=M, V=-1, J_V_ratio_routine = J_V_ratios, mu_V_ratio_routine = mu_V_ratios, times = times, dt = dt, initial_state = initial_state)
#
# ValueError: not enough values to unpack (expected 7, got 5)

# %%
fig, ax = plt.subplots()

ax.plot(times, np.real(adiabatic_overlaps[:,0]), "b")
ax.axvline(2*np.pi/J)
