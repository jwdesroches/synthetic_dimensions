# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
from synth_dim_model import *

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import random

# %%
# Parameters
N = 4
M = 4
mu = 10
V = 1

t_total_values = [10,100,500]  # List of t_total values to test
t_points = 100  # Higher resolution for better accuracy

# Prepare the figure
fig, ax = plt.subplots()

cmap = get_cmap("gist_rainbow", len(t_total_values))

for i, t_total in enumerate(t_total_values):
    color = cmap(i)
    # Random J/V ratio for each t_total
    J_V_ratio = 2
    J = J_V_ratio * V

    # Construct Hamiltonians
    H0 = construct_initial_hamiltonian(N, M, mu)
    Hf = construct_hamiltonian(N, M, J, V)

    # Initial state
    eigvals, eigvecs = np.linalg.eigh(H0)
    psi0 = eigvecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)  # Ensure normalization

    # Evolve the system
    t, psi_t = evolve_system(H0, Hf, psi0, t_total, t_points, interpolation_type = "linear")

    # Calculate ground state probabilities
    ground_state_prob = np.zeros_like(t)
    for i in range(len(t)):
        s = np.sin((np.pi/2) * (t[i] / t_total))**2
        H_s = construct_intermediate_hamiltonian(H0, Hf, s)
        _, eigvecs_s = exact_diagonalize(H_s)
        psi_ground_state_s = eigvecs_s[0]  # Ground state at time t
        ground_state_prob[i] = np.abs(np.dot(np.conjugate(psi_ground_state_s), psi_t[:, i]))**2

    # Plot the result for this t_total
    ax.plot(t/t_total, ground_state_prob, '.', color = color, label=f"$t_{{total}}$ = {t_total}")

# Customize the plot
ax.set_xlabel("Time [t/t_total]")
ax.set_ylabel("Ground State Probability")
ax.set_title(f"Adiabatic Evolution: N = {N}, M = {M}, J/V = {J_V_ratio}, $\mu$ = {mu}")
ax.set_ylim(0, 1.05)
ax.grid()
ax.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\jwdes\AppData\Local\Temp\ipykernel_15820\3547928197.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap("gist_rainbow", len(t_total_values))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 31
#      28 psi0 = psi0 / np.linalg.norm(psi0)  # Ensure normalization
#      30 # Evolve the system
# ---> 31 t, psi_t = evolve_system(H0, Hf, psi0, t_total, t_points, interpolation_type = "linear")
#      33 # Calculate ground state probabilities
#      34 ground_state_prob = np.zeros_like(t)
#
# File c:\Users\jwdes\python\synthetic_dimensions\synth_dim_model.py:469, in evolve_system(H0, Hf, psi0, t_total, t_points, interpolation_type)
#     466 t_eval = np.linspace(0, t_total, t_points)
#     468 # solve the TDSE using the solve_ivp function (Runge-Kutta 45 method)
# --> 469 sol = solve_ivp(
#     470     normalized_tdse, [0, t_total], psi0, t_eval=t_eval,
#     471     args=(H0, Hf, t_total, interpolation_type), method="RK45",
#     472     rtol=1e-10, atol=1e-12  # Set high precision
#     473 )
#     475 # return the evaluated time points and corresponding wavefunctions
#     476 return sol.t, sol.y
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\ivp.py:591, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     589 status = None
#     590 while status is None:
# --> 591     message = solver.step()
#     593     if solver.status == 'finished':
#     594         status = 0
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# File c:\Users\jwdes\anaconda3\envs\synthetic_dim\lib\site-packages\scipy\integrate\_ivp\ivp.py:529, in solve_ivp.<locals>.<lambda>(t, x, fun)
#     523     suggestion_tuple = (
#     524         "Supplied 'args' cannot be unpacked. Please supply `args`"
#     525         f" as a tuple (e.g. `args=({args},)`)"
#     526     )
#     527     raise TypeError(suggestion_tuple) from exp
# --> 529 fun = lambda t, x, fun=fun: fun(t, x, *args)
#     530 jac = options.get('jac')
#     531 if callable(jac):
#
# File c:\Users\jwdes\python\synthetic_dimensions\synth_dim_model.py:442, in normalized_tdse(t, psi, H0, Hf, t_total, interpolation_type)
#     439     s = 3 * (t / t_total)**2 - 2 * (t / t_total)**3  # smoothstep (cubic) interpolation
#     441 # construct the time-dependent hamiltonian
# --> 442 H_s = construct_intermediate_hamiltonian(H0, Hf, s)
#     444 # compute the time derivative of the wavefunction
#     445 return -1j * H_s.dot(psi)
#
# File c:\Users\jwdes\python\synthetic_dimensions\synth_dim_model.py:410, in construct_intermediate_hamiltonian(H0, Hf, s)
#     398 def construct_intermediate_hamiltonian(H0, Hf, s):
#     399     """
#     400     Construct an intermediate Hamiltonian as a linear interpolation between H0 and Hf.
#     401
#    (...)
#     408     np.ndarray: The interpolated Hamiltonian H(s) = H0 * (1-s) + Hf * s.
#     409     """
# --> 410     return H0 * (1 - s) + Hf * s
#
# KeyboardInterrupt:
