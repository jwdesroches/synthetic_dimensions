# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
from synth_dim_model import *

import numpy as np
import scipy
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
N = 2
M = 5

V = -1
mu_V_ratio = 0
J_V_ratio = 10

hamiltonian = construct_rescaled_hamiltonian(N,M,V,mu_V_ratio,J_V_ratio)
print(hamiltonian)
eigenvalues, eigenvectors = exact_diagonalize(hamiltonian)
# Out:
# [[  0.+0.j -10.+0.j   0.+0.j   0.+0.j   0.+0.j -10.+0.j   0.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [-10.+0.j   0.+0.j -10.+0.j   0.+0.j   0.+0.j  -1.+0.j -10.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j -10.+0.j   0.+0.j -10.+0.j   0.+0.j   0.+0.j   0.+0.j -10.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j -10.+0.j   0.+0.j -10.+0.j   0.+0.j   0.+0.j   0.+0.j
#   -10.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
# ...

# %%
T = 1000
beta = 1/T

part_func = np.trace(scipy.linalg.expm(-beta*hamiltonian))
print(part_func)
density_matrix = scipy.linalg.expm(-beta*hamiltonian)/part_func
print(np.shape(density_matrix))
# Out:
# (25.00400504387454+0j)
# (25, 25)
