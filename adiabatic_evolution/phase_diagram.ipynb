# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
from synth_dim_model import *

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings("ignore")

# %%
N = 2
M = 5

i = 0
j = 1

min_J_V_ratio = -2.5
max_J_V_ratio = 2.5

min_V_J_ratio = -2.5
max_V_J_ratio = 2.5

max_mu_value = 3

resolution = 1000


mu_values = np.linspace(0, max_mu_value, resolution)
J_V_ratio_values = np.linspace(min_J_V_ratio, max_J_V_ratio, resolution)
V_J_ratio_values = np.linspace(min_V_J_ratio, max_V_J_ratio, resolution)

energy_gap_cutoff = 0.1
energy_gap_cutoff_2 = 0.01
energy_gap_cutoff_3 = 0.001

# %%
mu_grid, J_V_ratio_grid = np.meshgrid(mu_values, J_V_ratio_values)
states, _ = enumerate_states(N, M)
sigma_grid = np.zeros_like(mu_grid)

V = 1

for idx1, mu in enumerate(mu_values):
    for idx2, J_V_ratio in enumerate(J_V_ratio_values):
        J = J_V_ratio * V
        
        H = construct_initial_hamiltonian(N, M, mu) + construct_hamiltonian(N, M, J, V)
        
        eigenvalues, eigenvectors = exact_diagonalize(H)
        ground_state_wavefunction = eigenvectors[0]
        
        sigma_grid[idx2,idx1] += [sigma_ij(i = i, j = j, ground_state_wavefunction = ground_state_wavefunction, states = states, N=N, M=M)/M]

# %%
plt.figure()

plt.pcolormesh(J_V_ratio_grid, mu_grid, sigma_grid, shading='auto', cmap='plasma')

plt.xlabel("$J/V$")
plt.ylabel("$\mu$")
if V > 0:
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $V>0$")
elif V < 0: 
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $V<0$")
plt.colorbar(label="$\sigma_{01}$")

plt.show()

# %%
mu_grid, V_J_ratio_grid = np.meshgrid(mu_values, V_J_ratio_values)
states, _ = enumerate_states(N, M)
sigma_grid = np.zeros_like(mu_grid)

J = 1

for idx1, mu in enumerate(mu_values):
    for idx2, V_J_ratio in enumerate(V_J_ratio_values):
        V = V_J_ratio * J
        
        H = construct_initial_hamiltonian(N, M, mu) + construct_hamiltonian(N, M, J, V)
        
        eigenvalues, eigenvectors = exact_diagonalize(H)
        ground_state_wavefunction = eigenvectors[0]
        
        sigma_grid[idx2,idx1] += [sigma_ij(i = i, j = j, ground_state_wavefunction = ground_state_wavefunction, states = states, N=N, M=M)/M]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 13
#       9 V = V_J_ratio * J
#      11 H = construct_initial_hamiltonian(N, M, mu) + construct_hamiltonian(N, M, J, V)
# ---> 13 eigenvalues, eigenvectors = exact_diagonalize(H)
#      14 ground_state_wavefunction = eigenvectors[0]
#      16 sigma_grid[idx2,idx1] += [sigma_ij(i = i, j = j, ground_state_wavefunction = ground_state_wavefunction, states = states, N=N, M=M)/M]
#
# File c:\Users\jwdes\python\synthetic_dimensions\synth_dim_model.py:260, in exact_diagonalize(H, use_sparse, k, verbose, check_reconstruction)
#     246 def exact_diagonalize(H, use_sparse = False, k = 1, verbose=False, check_reconstruction=False):
#     247     """
#     248     Diagonalizes a Hermitian matrix using numpy's `eigh()` method.
#     249
#    (...)
#     257     list: List of eigenvectors of the matrix.
#     258     """
# --> 260     if not np.allclose(np.conjugate(H.T), H):
#     261             print("The matrix is not Hermitian.")
#     262             return None, None
#
# KeyboardInterrupt:

# %%
plt.figure()

plt.pcolormesh(V_J_ratio_grid, mu_grid, sigma_grid, shading='auto', cmap='plasma')

plt.xlabel("$V/J$")
plt.ylabel("$\mu$")
if J > 0:
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $J>0$")
elif J < 0: 
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $J<0$")
plt.colorbar(label="$\sigma_{01}$")

plt.show()

# %%
mu_grid, V_J_ratio_grid = np.meshgrid(mu_values, V_J_ratio_values)
states, _ = enumerate_states(N, M)
sigma_grid = np.zeros_like(mu_grid)

J = -1

for idx1, mu in enumerate(mu_values):
    for idx2, V_J_ratio in enumerate(V_J_ratio_values):
        V = V_J_ratio * J
        
        H = construct_initial_hamiltonian(N, M, mu) + construct_hamiltonian(N, M, J, V)
        
        eigenvalues, eigenvectors = exact_diagonalize(H)
        ground_state_wavefunction = eigenvectors[0]
        
        sigma_grid[idx2,idx1] += [sigma_ij(i = i, j = j, ground_state_wavefunction = ground_state_wavefunction, states = states, N=N, M=M)/M]

# %%
plt.figure()

plt.pcolormesh(V_J_ratio_grid, mu_grid, sigma_grid, shading='auto', cmap='plasma')

plt.xlabel("$V/J$")
plt.ylabel("$\mu$")
if J > 0:
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $J>0$")
elif J < 0: 
    plt.title("$\sigma_{01}$ Order Parameter:"+f" $N=${N}, $M=${M}, $J<0$")
plt.colorbar(label="$\sigma_{01}$")

plt.show()
