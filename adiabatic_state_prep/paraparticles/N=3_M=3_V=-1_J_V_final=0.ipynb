# %%
import sys
import os

# Go up two levels
grandparent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(grandparent_dir)

# Path to a subdirectory inside that grandparent directory
data_folder_path = os.path.join(grandparent_dir, "data_folder")
sys.path.append(data_folder_path)

from synth_dim_model import *
from plotting_utils import *

import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import concurrent.futures
plt.rcParams.update({'font.size': 12})

# %%
N = 3
M = 3
V = -1
dt = 0.1

J_V_init = 0.1
J_V_final = 0
mu_V_init = 10
mu_V_final = 0

num_control_points = 12

Ts = np.linspace(0.1,10,25)
ground_state_overlaps = []
energy_differences = []

opt_params = None

for T in Ts:
    
    print(f"\nOptimizing for T = {T}")
    
    results = create_optimal_piecewise_linear_paths(
        N, M, T, dt, V,
        J_V_init, J_V_final,
        mu_V_init, mu_V_final,
        num_control_points,
        initial_guess=opt_params
    )
    
    times_dense, J_V_path, mu_V_path, obj_value, opt_params, t_control_opt, J_control_opt, mu_control_opt = results
    
    hamiltonians = [construct_rescaled_hamiltonian(N, M, V, mu_V_ratio=mu_V_path[i], J_V_ratio=J_V_path[i]) for i in range(len(times_dense))]
    final_results = simulate_hamiltonian_time_evolution(hamiltonians, times_dense)
    energies, time_evolved_wavefunctions, state_probabilities, state_overlaps, true_energies, ground_state_manifold_overlaps = final_results
    gso = ground_state_manifold_overlaps[-1]
    ground_state_overlaps.append(gso)
    ed = energies[-1] - true_energies[-1,0]
    energy_differences.append(ed)
    
    print(f"GROUND_STATE_OVERLAP: {gso:.6f}")
    print(f"ENERGY_DIFFERENCE: {ed:.6f}")
    print()
    
print("All finished:")
print(f"Evolution Times: {Ts}")
print(f"Ground State Overlaps = {ground_state_overlaps}")
print(f"Energy Differences = {ground_state_overlaps}")
# Out:
# Optimizing for T = 0.1
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.9996048142445788
#             Iterations: 1
#             Function evaluations: 31
#             Gradient evaluations: 1
# Success: True
# GROUND_STATE_OVERLAP: 0.000395
# ENERGY_DIFFERENCE: 1.413664
#
#
# Optimizing for T = 0.5125000000000001
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3009482810651366
#             Iterations: 61
#             Function evaluations: 1914
#             Gradient evaluations: 61
# Success: True
# GROUND_STATE_OVERLAP: 0.775004
# ENERGY_DIFFERENCE: 0.334248
#
#
# Optimizing for T = 0.925
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.21141574707978117
#             Iterations: 47
#             Function evaluations: 1532
#             Gradient evaluations: 47
# Success: True
# GROUND_STATE_OVERLAP: 0.823961
# ENERGY_DIFFERENCE: 0.261232
#
#
# Optimizing for T = 1.3375000000000001
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.16128556570521227
#             Iterations: 92
#             Function evaluations: 2952
#             Gradient evaluations: 92
# Success: True
# GROUND_STATE_OVERLAP: 0.863846
# ENERGY_DIFFERENCE: 0.201811
#
#
# Optimizing for T = 1.7500000000000002
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.12966805358250522
#             Iterations: 26
#             Function evaluations: 879
#             Gradient evaluations: 26
# Success: True
# GROUND_STATE_OVERLAP: 0.887622
# ENERGY_DIFFERENCE: 0.166959
#
#
# Optimizing for T = 2.1625
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.10360139360803064
#             Iterations: 33
#             Function evaluations: 1078
#             Gradient evaluations: 33
# Success: True
# GROUND_STATE_OVERLAP: 0.909457
# ENERGY_DIFFERENCE: 0.133099
#
#
# Optimizing for T = 2.575
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.054957331313111785
#             Iterations: 101
#             Function evaluations: 3193
#             Gradient evaluations: 101
# Success: True
# GROUND_STATE_OVERLAP: 0.966330
# ENERGY_DIFFERENCE: 0.051840
#
#
# Optimizing for T = 2.9875000000000003
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.03509208179527237
#             Iterations: 25
#             Function evaluations: 817
#             Gradient evaluations: 25
# Success: True
# GROUND_STATE_OVERLAP: 0.985778
# ENERGY_DIFFERENCE: 0.021412
#
#
# Optimizing for T = 3.4000000000000004
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.026085215433187803
#             Iterations: 80
#             Function evaluations: 2538
#             Gradient evaluations: 80
# Success: True
# GROUND_STATE_OVERLAP: 0.991892
# ENERGY_DIFFERENCE: 0.013081
#
#
# Optimizing for T = 3.8125000000000004
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.011264247580201149
#             Iterations: 99
#             Function evaluations: 3102
#             Gradient evaluations: 99
# Success: True
# GROUND_STATE_OVERLAP: 0.995908
# ENERGY_DIFFERENCE: 0.007206
#
#
# Optimizing for T = 4.225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.007818593864986047
#             Iterations: 79
#             Function evaluations: 2482
#             Gradient evaluations: 79
# Success: True
# GROUND_STATE_OVERLAP: 0.996754
# ENERGY_DIFFERENCE: 0.006277
#
#
# Optimizing for T = 4.6375
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.005698290833452147
#             Iterations: 84
#             Function evaluations: 2617
#             Gradient evaluations: 84
# Success: True
# GROUND_STATE_OVERLAP: 0.997388
# ENERGY_DIFFERENCE: 0.005428
#
#
# Optimizing for T = 5.05
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.004156143594870376
#             Iterations: 144
#             Function evaluations: 4517
#             Gradient evaluations: 144
# Success: True
# GROUND_STATE_OVERLAP: 0.998037
# ENERGY_DIFFERENCE: 0.004192
#
#
# Optimizing for T = 5.4625
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0033176782404428897
#             Iterations: 72
#             Function evaluations: 2256
#             Gradient evaluations: 72
# Success: True
# GROUND_STATE_OVERLAP: 0.998598
# ENERGY_DIFFERENCE: 0.003102
#
#
# Optimizing for T = 5.875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0027697248703292933
#             Iterations: 60
#             Function evaluations: 1873
#             Gradient evaluations: 60
# Success: True
# GROUND_STATE_OVERLAP: 0.998870
# ENERGY_DIFFERENCE: 0.002493
#
#
# Optimizing for T = 6.2875000000000005
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.002051874678434174
#             Iterations: 81
#             Function evaluations: 2525
#             Gradient evaluations: 81
# Success: True
# GROUND_STATE_OVERLAP: 0.999248
# ENERGY_DIFFERENCE: 0.001696
#
#
# Optimizing for T = 6.7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0016727913655989468
#             Iterations: 78
#             Function evaluations: 2431
#             Gradient evaluations: 78
# Success: True
# GROUND_STATE_OVERLAP: 0.999431
# ENERGY_DIFFERENCE: 0.001304
#
#
# Optimizing for T = 7.1125
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0013647236360435854
#             Iterations: 78
#             Function evaluations: 2438
#             Gradient evaluations: 78
# Success: True
# GROUND_STATE_OVERLAP: 0.999552
# ENERGY_DIFFERENCE: 0.001010
#
#
# Optimizing for T = 7.525
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0011806816558352028
#             Iterations: 80
#             Function evaluations: 2510
#             Gradient evaluations: 80
# Success: True
# GROUND_STATE_OVERLAP: 0.999637
# ENERGY_DIFFERENCE: 0.000818
#
#
# Optimizing for T = 7.9375
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0010606604587059866
#             Iterations: 75
#             Function evaluations: 2349
#             Gradient evaluations: 75
# Success: True
# GROUND_STATE_OVERLAP: 0.999686
# ENERGY_DIFFERENCE: 0.000700
#
#
# Optimizing for T = 8.35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000984641476250614
#             Iterations: 54
#             Function evaluations: 1708
#             Gradient evaluations: 54
# Success: True
# GROUND_STATE_OVERLAP: 0.999704
# ENERGY_DIFFERENCE: 0.000645
#
#
# Optimizing for T = 8.762500000000001
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000937583038862444
#             Iterations: 49
#             Function evaluations: 1528
#             Gradient evaluations: 49
# Success: True
# GROUND_STATE_OVERLAP: 0.999714
# ENERGY_DIFFERENCE: 0.000615
#
#
# Optimizing for T = 9.175
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0007995607020185869
#             Iterations: 111
#             Function evaluations: 3471
#             Gradient evaluations: 111
# Success: True
# GROUND_STATE_OVERLAP: 0.999794
# ENERGY_DIFFERENCE: 0.000474
#
#
# Optimizing for T = 9.5875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0007226650162418524
#             Iterations: 79
#             Function evaluations: 2465
#             Gradient evaluations: 79
# Success: True
# GROUND_STATE_OVERLAP: 0.999818
# ENERGY_DIFFERENCE: 0.000424
#
#
# Optimizing for T = 10.0
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000657106563794585
#             Iterations: 59
#             Function evaluations: 1841
#             Gradient evaluations: 59
# Success: True
# GROUND_STATE_OVERLAP: 0.999840
# ENERGY_DIFFERENCE: 0.000380
#
# All finished:
# Evolution Times: [ 0.1     0.5125  0.925   1.3375  1.75    2.1625  2.575   2.9875  3.4
#   3.8125  4.225   4.6375  5.05    5.4625  5.875   6.2875  6.7     7.1125
#   7.525   7.9375  8.35    8.7625  9.175   9.5875 10.    ]
# Ground State Overlaps = [np.float64(0.0003951857554213799), np.float64(0.775004435701875), np.float64(0.8239609938978921), np.float64(0.8638456220250079), np.float64(0.8876216913445658), np.float64(0.9094566515817729), np.float64(0.9663298854548655), np.float64(0.9857783804691187), np.float64(0.9918923994185914), np.float64(0.9959080382928897), np.float64(0.9967543829175907), np.float64(0.9973883466981006), np.float64(0.9980368402977414), np.float64(0.998598469019689), np.float64(0.9988697148382426), np.float64(0.9992481497369342), np.float64(0.9994311529890583), np.float64(0.9995518868455058), np.float64(0.9996367214974258), np.float64(0.9996862458341534), np.float64(0.9997043822696912), np.float64(0.9997140817451784), np.float64(0.9997939063555477), np.float64(0.999818104942002), np.float64(0.9998404445998483)]
# Energy Differences = [np.float64(0.0003951857554213799), np.float64(0.775004435701875), np.float64(0.8239609938978921), np.float64(0.8638456220250079), np.float64(0.8876216913445658), np.float64(0.9094566515817729), np.float64(0.9663298854548655), np.float64(0.9857783804691187), np.float64(0.9918923994185914), np.float64(0.9959080382928897), np.float64(0.9967543829175907), np.float64(0.9973883466981006), np.float64(0.9980368402977414), np.float64(0.998598469019689), np.float64(0.9988697148382426), np.float64(0.9992481497369342), np.float64(0.9994311529890583), np.float64(0.9995518868455058), np.float64(0.9996367214974258), np.float64(0.9996862458341534), np.float64(0.9997043822696912), np.float64(0.9997140817451784), np.float64(0.9997939063555477), np.float64(0.999818104942002), np.float64(0.9998404445998483)]

# %%
plt.figure(figsize=(8,5))
plt.plot(Ts, ground_state_overlaps, marker='o', color = "blue")
plt.xlabel('Total Evolution Time $T$')
plt.ylabel('$\langle \psi(T) | P_D | \psi(T) \\rangle$')
plt.title(f'GS Manifold Overlap vs Total Time: $N = {N}$, $M = {M}$, $V = {V}$, $(J/|V|)_f = {J_V_final}$')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(Ts, energy_differences, marker='o', color = "red")
plt.xlabel('Total Evolution Time $T$')
plt.ylabel('$E(T) - E_0$')
plt.title(f'Energy Difference vs Total Time: $N = {N}$, $M = {M}$, $V = {V}$, $(J/|V|)_f = {J_V_final}$')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
if V > 0:
    plot_data(N, M, sign_V = "positive", gap_or_sigma="energy_gap", include_path=True, mu_V_ratios=mu_V_path, J_V_ratios=J_V_path, times=times_dense)
else:
    plot_data(N, M, sign_V = "negative", gap_or_sigma="energy_gap", include_path=True, mu_V_ratios=mu_V_path, J_V_ratios=J_V_path, times=times_dense):
# Out:
#   Cell In[4], line 4
#     plot_data(N, M, sign_V = "negative", gap_or_sigma="energy_gap", include_path=True, mu_V_ratios=mu_V_path, J_V_ratios=J_V_path, times=times_dense):
#                                                                                                                                                      ^
# SyntaxError: invalid syntax
